# %% [markdown]
# **Sentimen Analisis Aplikasi PUBG Mobile di play store**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews
from google_play_scraper import app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.tencent.ig',
    lang='id', #bahasa
    country='id', #negara
    sort=Sort.MOST_RELEVANT, #sorting yang paling relevan
    count=1000, #jumlah dataset
    filter_score_with= None
)

# %%
# Dataframe dengan nama
data = pd.DataFrame(np.array(result),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId      userName  \
# 0  aeee81a5-5e1f-4215-be58-0bce60945976   Fahru rozik
# 1  cc869620-6927-4210-87fa-9caef50a14a3      pras tyo
# 2  c400d04e-29b5-4bf2-ae82-3bc614fd0144         Zacky
# 3  73d8d15b-323f-47bd-b451-107b317787c7  Levi Ibrahim
# 4  e797e8a4-9783-47cc-9bcb-df12b7978e0c   Ikmal Hatta
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3            432
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1            652
# 2  Parah sangat parah, setelah di update bug dima...      2             38
# 3  setelah update 2.9 game playnya makin aneh ban...      1              3
# 4  setelah update patch versi 2.9.0 sekarang bany...      1            615
#
#   reviewCreatedVersion                  at  \
# 0                2.9.0 2023-11-14 12:49:35
# 1                2.9.0 2023-11-10 14:37:25
# 2                2.9.0 2023-11-18 04:17:08
# 3                2.9.0 2023-11-18 01:38:54
# 4                2.9.0 2023-11-11 01:48:23
#
#                                         replyContent           repliedAt  \
# 0  Yang terhormat pemain, \nKami sangat mementing... 2023-11-15 02:00:51
# 1  Yang terhormat pemain,\nKami sanagt mementingk... 2023-10-27 06:03:48
# 2  Yang terhormat pemain,\nKami sangat mementingk... 2023-11-18 08:53:07
# 3  Yang terhormat pemain,\nKami sangat mementingk... 2023-11-18 08:01:36
# 4  Pemain yang terhormat,\nKami menyesal bahwa An... 2023-11-11 02:30:32
#
#   appVersion
# 0      2.9.0
# 1      2.9.0
# 2      2.9.0
# 3      2.9.0
# 4      2.9.0

# %%
len(data)
# Out:
# 1000

# %%
data = data[['content','score']]
data.head()
# Out:
#                                              content  score
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1
# 2  Parah sangat parah, setelah di update bug dima...      2
# 3  setelah update 2.9 game playnya makin aneh ban...      1
# 4  setelah update patch versi 2.9.0 sekarang bany...      1

# %%
data = data.rename(columns={'content': 'komentar','score': 'value'}) #mengganti nama fitur
data.head()
# Out:
#                                             komentar  value
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1
# 2  Parah sangat parah, setelah di update bug dima...      2
# 3  setelah update 2.9 game playnya makin aneh ban...      1
# 4  setelah update patch versi 2.9.0 sekarang bany...      1

# %%
data.to_csv("komentar pubgm 1000 Data.csv", index = False , encoding='utf-8')

# %%
dataPubgm = pd.read_csv('/content/komentar pubgm 1000 Data.csv')
dataPubgm.head()
# Out:
#                                             komentar  value
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1
# 2  Parah sangat parah, setelah di update bug dima...      2
# 3  setelah update 2.9 game playnya makin aneh ban...      1
# 4  setelah update patch versi 2.9.0 sekarang bany...      1

# %% [markdown]
# SCRAPING DATA

# %%
df = pd.read_csv('komentar pubgm 1000 Data.csv')

# %%
df.head(10)
# Out:
#                                             komentar  value
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1
# 2  Parah sangat parah, setelah di update bug dima...      2
# 3  setelah update 2.9 game playnya makin aneh ban...      1
# 4  setelah update patch versi 2.9.0 sekarang bany...      1
# 5  Saya sangat kecewa dengan update terbaru...ban...      1
# 6  Event nya selalu low respon padahal tidak ada ...      1
# 7  Bagus, bagus banget malah. Tapi ada satu kenda...      2
# 8  Mohon dapat di perhatikan pada sisi bug yang t...      5
# 9  Setelah update versinya terbaru sekarang ada b...      5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
data = pd.read_csv('komentar pubgm 1000 Data.csv')

# %%
data.head()
# Out:
#                                             komentar  value
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...      3
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....      1
# 2  Parah sangat parah, setelah di update bug dima...      2
# 3  setelah update 2.9 game playnya makin aneh ban...      1
# 4  setelah update patch versi 2.9.0 sekarang bany...      1

# %%
# menghilangkan baris yang memiliki nilai null/kosong
data = data.dropna()

# menghilangkan tanda baca dan karakter khusus
data['clean_text'] = data['komentar'].str.replace('[^\w\s]', '')

# mengubah teks menjadi huruf kecil
data['clean_text'] = data['clean_text'].str.lower()

# menghilangkan stop words (kata umum yang tidak memberikan informasi tambahan)
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
data['clean_text'] = data['clean_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Out:
# <ipython-input-16-9892ad7e833d>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['clean_text'] = data['komentar'].str.replace('[^\w\s]', '')
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# menggabungkan semua komentar menjadi satu teks
all_text = ' '.join(data['clean_text'])

# membuat word cloud
wordcloud = WordCloud(width=1000, height=500, max_font_size=150, random_state=42).generate(all_text)

# menampilkan Word Cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('indonesian'))
stop_words.update(['dan', 'yang', 'lalu', 'yg', 'gk', 'saya', 'lagi'])

# %%
data['clean_text'] = data['komentar'].str.replace('[^\w\s]', '')
data['clean_text'] = data['clean_text'].str.lower()
data['clean_text'] = data['clean_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Out:
# <ipython-input-20-4b9e009902b3>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['clean_text'] = data['komentar'].str.replace('[^\w\s]', '')

# %%
all_text = ' '.join(data['clean_text'])

wordcloud = WordCloud(width=1000, height=500, max_font_size=150, random_state=42).generate(all_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# Melakukan Sentimental Analisis

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# menginisialisasi SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# menghitung snetimen untuk setiap komentar
data['sentiment'] = data['clean_text'].apply(lambda x: sia.polarity_scores(x)['compound'])

# melabeli sentimen (misal 'positif' , 'negatif' , 'netral') berdasarkan nilai sentimen
data['sentiment_label'] = data['sentiment'].apply(lambda x: 'positif' if x > 0 else ('negatif' if x < 0 else 'netral'))

# %%
# menampilkan beberapa komentar dan sentimen terkait
data[['komentar', 'sentiment_label']].head(10)
# Out:
#                                             komentar sentiment_label
# 0  Setelah Update 2.9 Saya kira Bug yang pernah s...          netral
# 1  Setelah ubdate 2.9 harus nya bug sudah hilang....          netral
# 2  Parah sangat parah, setelah di update bug dima...         negatif
# 3  setelah update 2.9 game playnya makin aneh ban...          netral
# 4  setelah update patch versi 2.9.0 sekarang bany...         negatif
# 5  Saya sangat kecewa dengan update terbaru...ban...          netral
# 6  Event nya selalu low respon padahal tidak ada ...         negatif
# 7  Bagus, bagus banget malah. Tapi ada satu kenda...         positif
# 8  Mohon dapat di perhatikan pada sisi bug yang t...         negatif
# 9  Setelah update versinya terbaru sekarang ada b...          netral

# %%
data.to_csv("hasil komentar pubgm 1000 Data.csv", index = False , encoding='utf-8')
